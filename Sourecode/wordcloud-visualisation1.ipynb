# %%
import numpy as np
import pandas as pd 
import matplotlib as mp
import matplotlib.pyplot as plt
# %matplotlib inline
from wordcloud import WordCloud, STOPWORDS

mp.rcParams['figure.figsize']=(20,20)    
mp.rcParams['font.size']=11               
mp.rcParams['savefig.dpi']=90         
mp.rcParams['figure.subplot.bottom']=.1 


stopword = set(STOPWORDS)
data = pd.read_csv("C:/Users/poorn/Downloads/crime-in-los-angeles/Crime.csv")

wc = WordCloud(
                          background_color='black',
                          stopwords=stopword,
                          max_words=150,
                          max_font_size=38, 
                          random_state=42
                         ).generate(str(data['Crime Code Description']))

print(wordcloud)
wordcloud = plt.figure(1)
plt.imshow(wc)
plt.axis('off')
plt.show()
# Out:
# Figure(1440x1440)
